# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://xsc80456:bgxwrc9rff-fw8jv@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Out:
# 'Connected: xsc80456@BLUDB'

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from syscat.tables where tabschema = 'XSC80456'
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('XSC80456', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2019, 9, 30, 19, 25, 19, 916261)),
#  ('XSC80456', 'SCHOOLS', datetime.datetime(2019, 9, 30, 19, 41, 56, 411442)),
#  ('XSC80456', 'INSTRUCTOR', datetime.datetime(2019, 9, 17, 21, 54, 2, 71447)),
#  ('XSC80456', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2019, 9, 17, 22, 10, 29, 931390)),
#  ('XSC80456', 'EMPLOYEES', datetime.datetime(2019, 8, 8, 22, 1, 14, 959796)),
#  ('XSC80456', 'JOB_HISTORY', datetime.datetime(2019, 8, 8, 22, 1, 15, 116761)),
#  ('XSC80456', 'LOCATIONS', datetime.datetime(2019, 8, 8, 22, 1, 15, 546692)),
#  ('XSC80456', 'DEPARTMENTS', datetime.datetime(2019, 8, 8, 22, 18, 59, 382454)),
#  ('XSC80456', 'JOBS', datetime.datetime(2019, 8, 8, 22, 41, 10, 856835)),
#  ('XSC80456', 'PETSALE', datetime.datetime(2019, 8, 23, 4, 40, 54, 955683))]

# %%
# %sql select * from syscat.columns where TABNAME='SCHOOLS'
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('XSC80456', 'SCHOOLS', 'Parent_Engagement_Score', 29, 'SYSIBM  ', 'VARCHAR', 3, 0, 'OCTETS', 3, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 32, "'69'", "'39'", 7, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 2, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('XSC80456', 'SCHOOLS', 'Parent_Environment_Icon', 30, 'SYSIBM  ', 'VARCHAR', 7, 0, 'OCTETS', 7, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 4, "'Strong'", "'NDA'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select distinct(colname), typename, length from syscat.columns where TABNAME='SCHOOLS'
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('10th Grade PLAN (2009)', 'VARCHAR', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR', 4),
#  ('11th Grade Average ACT (2011)', 'VARCHAR', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR', 4),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR', 6),
#  ('Adequate_Yearly_Progress_Made_', 'VARCHAR', 3),
#  ('Average_Teacher_Attendance', 'VARCHAR', 6),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('CPS_Performance_Policy_Level', 'VARCHAR', 15),
#  ('CPS_Performance_Policy_Status', 'VARCHAR', 16),
#  ('City', 'VARCHAR', 7),
#  ('Collaborative_Name', 'VARCHAR', 34),
#  ('College_Eligibility__', 'VARCHAR', 4),
#  ('College_Enrollment_Rate__', 'VARCHAR', 4),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('Environment_Icon', 'VARCHAR', 11),
# ...

# %% [markdown]
# ##Questions
#
# #Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
#
# mixed
#
# What is the name of "Community Area Name" column in your table? Does it have spaces?
# COMMUNITY_AREA_NAME
#
# Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "_"?
#
# YES, ALL SPACES, PARANTHESIS REPLACED WITH _

# %%
#Q1

# %sql select count(*) from SCHOOLS where "Elementary, Middle, or High School" = 'ES';
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('462'),)]

# %%
#Q2
# %sql select max(safety_score) as "max_safety_score" from SCHOOLS;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(99,)]

# %%
#Q3

# %sql select NAME_OF_SCHOOL from SCHOOLS where  (select max(safety_score) from SCHOOLS) = safety_score;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %%
#Q4

# %sql select NAME_OF_SCHOOL as "School Name", Average_Student_Attendance from SCHOOLS order by AVERAGE_STUDENT_ATTENDANCE desc nulls last limit 10;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %%
#Q5

# %sql select NAME_OF_SCHOOL as "School Name", Average_Student_Attendance from SCHOOLS order by AVERAGE_STUDENT_ATTENDANCE nulls last limit 5;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
#Q6

# %sql select NAME_OF_SCHOOL as "School Name", replace(Average_Student_Attendance,'%','') as "Average Student Attendance" from SCHOOLS order by AVERAGE_STUDENT_ATTENDANCE nulls last limit 5;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %%
#Q7

# %sql select NAME_OF_SCHOOL as "School Name", Average_Student_Attendance as "Average Student Attendance" from SCHOOLS where cast(replace(Average_Student_Attendance,'%','') as decimal) < 70 order by AVERAGE_STUDENT_ATTENDANCE nulls last;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
#Q8

# %sql select community_area_number, community_area_name, sum(college_enrollment) as "Total Enrollment" from SCHOOLS group by community_area_name, community_area_number ;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(1, 'ROGERS PARK', 4068),
#  (2, 'WEST RIDGE', 8197),
#  (3, 'UPTOWN', 4388),
#  (4, 'LINCOLN SQUARE', 4132),
#  (5, 'NORTH CENTER', 7541),
#  (6, 'LAKE VIEW', 7055),
#  (7, 'LINCOLN PARK', 5615),
#  (8, 'NEAR NORTH SIDE', 3362),
#  (9, 'EDISON PARK', 910),
#  (10, 'NORWOOD PARK', 6469),
#  (11, 'JEFFERSON PARK', 1755),
#  (12, 'FOREST GLEN', 1431),
#  (13, 'NORTH PARK', 4210),
#  (14, 'ALBANY PARK', 6864),
#  (15, 'PORTAGE PARK', 6954),
#  (16, 'IRVING PARK', 7764),
#  (17, 'DUNNING', 4568),
#  (18, 'MONTCLARE', 1317),
#  (19, 'BELMONT CRAGIN', 14386),
#  (20, 'HERMOSA', 3975),
#  (21, 'AVONDALE', 3640),
#  (22, 'LOGAN SQUARE', 7351),
#  (23, 'HUMBOLDT PARK', 8620),
#  (24, 'WEST TOWN', 9429),
#  (25, 'AUSTIN', 10933),
#  (26, 'WEST GARFIELD PARK', 2622),
#  (27, 'EAST GARFIELD PARK', 5337),
#  (28, 'NEAR WEST SIDE', 7975),
#  (29, 'NORTH LAWNDALE', 5146),
# ...

# %%
#Q9

# %sql select community_area_number, community_area_name, sum(college_enrollment) as "Total Enrollment" from SCHOOLS group by community_area_name, community_area_number order by "Total Enrollment"
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(36, 'OAKLAND', 140),
#  (37, 'FULLER PARK', 531),
#  (47, 'BURNSIDE', 549),
#  (76, 'OHARE', 786),
#  (32, 'LOOP', 871),
#  (9, 'EDISON PARK', 910),
#  (55, 'HEGEWISCH', 963),
#  (18, 'MONTCLARE', 1317),
#  (33, 'NEAR SOUTH SIDE', 1378),
#  (12, 'FOREST GLEN', 1431),
#  (34, 'ARMOUR SQUARE', 1458),
#  (45, 'AVALON PARK', 1522),
#  (54, 'RIVERDALE', 1547),
#  (59, 'MCKINLEY PARK', 1552),
#  (48, 'CALUMET HEIGHTS', 1568),
#  (50, 'PULLMAN', 1620),
#  (72, 'BEVERLY', 1636),
#  (11, 'JEFFERSON PARK', 1755),
#  (51, 'SOUTH DEERING', 1859),
#  (41, 'HYDE PARK', 1930),
#  (64, 'CLEARING', 2085),
#  (74, 'MOUNT GREENWOOD', 2091),
#  (26, 'WEST GARFIELD PARK', 2622),
#  (40, 'WASHINGTON PARK', 2648),
#  (38, 'GRAND BOULEVARD', 2809),
#  (60, 'BRIDGEPORT', 3167),
#  (53, 'WEST PULLMAN', 3240),
#  (75, 'MORGAN PARK', 3271),
#  (8, 'NEAR NORTH SIDE', 3362),
#  (21, 'AVONDALE', 3640),
# ...

# %%
#Q10
# %sql select hardship_index from  CHICAGO_SOCIOECONOMIC_DATA C, SCHOOLS S where C.ca=S.community_area_number and S.college_enrollment=4368;
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(6.0,)]

# %%
#Q11
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
   where ca in \
   ( select community_area_number from schools order by college_enrollment desc limit 1 )
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(5.0, 'North Center', 6.0)]

# %%
# Out:
#  * ibm_db_sa://xsc80456:***@dashdb-txn-sbox-yp-dal09-03.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(6.0,)]
